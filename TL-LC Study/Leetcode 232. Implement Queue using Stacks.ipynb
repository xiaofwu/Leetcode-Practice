# %%
"""
232. Implement Queue using Stacks
Implement a first in first out (FIFO) queue using only two stacks. The implemented queue should support all the functions of a normal queue (push, peek, pop, and empty).

Implement the MyQueue class:

void push(int x) Pushes element x to the back of the queue.
int pop() Removes the element from the front of the queue and returns it.
int peek() Returns the element at the front of the queue.
boolean empty() Returns true if the queue is empty, false otherwise.
"""

class MyQueue:

    def __init__(self):
        self.queue = []

    def push(self, x):
        return self.queue.append(x)
        

    def pop(self):
        if self.queue:
            del self.queue[0]
            return self.queue
        else:
            return None
        

    def peek(self):
        if self.queue:
            return self.queue[-1]
        else:
            return None
        

    def empty(self):
        if self.queue:
            return False
        else:
            return True


# Your MyQueue object will be instantiated and called as such:
# obj = MyQueue()
# obj.push(x)
# param_2 = obj.pop()
# param_3 = obj.peek()
# param_4 = obj.empty()

# %% [markdown]
# 方法一（使用两个栈 入队 - O(n)O(n)， 出队 - O(1)O(1)）
# 算法
#
# 入队（push）
# 一个队列是 FIFO 的，但一个栈是 LIFO 的。这就意味着最新压入的元素必须得放在栈底。为了实现这个目的，我们首先需要把 s1 中所有的元素移到 s2 中，接着把新元素压入 s2。最后把 s2 中所有的元素弹出，再把弹出的元素压入 s1。
#
# 复杂度分析:
# 1) 时间复杂度：O(n)O(n)
# 对于除了新元素之外的所有元素，它们都会被压入两次，弹出两次。新元素只被压入一次，弹出一次。这个过程产生了 4n + 24n+2 次操作，其中 nn 是队列的大小。由于 压入 操作和 弹出 操作的时间复杂度为 O(1)O(1)， 所以时间复杂度为 O(n)O(n)。
# 2) 空间复杂度：O(n)O(n)
# 需要额外的内存来存储队列中的元素。
#
#
# 出队（pop）
# 直接从 s1 弹出就可以了，因为 s1 的栈顶元素就是队列的队首元素。同时我们把弹出之后 s1 的栈顶元素赋值给代表队首元素的 front 变量。
# 复杂度分析
#
# 1) 时间复杂度：O(1)O(1)
# 2) 空间复杂度：O(1)O(1)
#
# 判断空（empty）
#
# s1 存储了队列所有的元素，所以只需要检查 s1 的是否为空就可以了。
# 1) 时间复杂度：O(1)O(1)
# 1) 空间复杂度：O(1)O(1)

# %%
# 2022-10-03
class MyQueue:

    def __init__(self):
        """
        Initialize your data structure here.
        """
        self.stack1 = []
        self.stack2 = []

    def push(self, x: int) -> None:
        """
        Push element x to the back of queue.
        """
        # For a queue, last element is last out
        # since we are using stack to implement a queue, and stack pops last element
        # we need to move x to the front of a stack
        # To achieve this, we evacuate stack1 and move all element to stack2
        # then we append x to stack1
        # then we move all element back from stack2 
        # we end up with all elements in stack1 with x in the front.
        while self.stack1:
            stack2.append(self.stack1.pop())
        
        self.stack1.append(x)
        
        while stack2:
            self.stack1.append(stack2.pop())

    def pop(self) -> int:
        """
        Removes the element from the front of a queue and returns that element.
        """
        return self.stack1.pop()

    def peek(self) -> int:
        """
        Get the front element.
        """
        return self.stack1[-1]

    def empty(self) -> bool:
        """
        Returns whether the queue is empty.
        """
        return len(self.stack1) == 0
